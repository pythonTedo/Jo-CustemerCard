# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("data/Filialdaten.xlsx", index_col="FILIALE")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 942 entries, 1 to 942
# Data columns (total 18 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   B_LAND                                         942 non-null    int64
#  1   VERKAUFS_M2                                    942 non-null    float64
#  2   Umsatz                                         942 non-null    float64
#  3   Kund. Anz.                                     942 non-null    int64
#  4   Aktionsanteil                                  942 non-null    float64
#  5   Anteil Clever                                  942 non-null    float64
#  6   Anteil Ja!Natürlich                            942 non-null    float64
#  7   Anteil Feinkost                                942 non-null    float64
#  8   Anteil Obst&Gemüse                             942 non-null    float64
#  9   Anteil BILLA Marke                             942 non-null    float64
#  10  Anteil BILLA Corso                             942 non-null    float64
#  11  Anteil Getränke ohne Alkohol                   942 non-null    float64
#  12  Anteil Alkohol                                 942 non-null    float64
#  13  ANZAHL_Verbrauchermärkte_im Umkreis von 20min  888 non-null    float64
#  14  ANZAHL_Diskonter_im Umkreis von 20min          931 non-null    float64
#  15  KaufKraft_Drogeriefachhandel_KOPF              942 non-null    float64
#  16  KaufKraft_Lebensmittelhandel_KOPF              942 non-null    float64
#  17  Kaufkraft_KOPF                                 942 non-null    float64
# dtypes: float64(16), int64(2)
# memory usage: 139.8 KB

# %% [markdown]
# # Load data and Data analysis

# %%
df.head()
# Out:
#          B_LAND  VERKAUFS_M2         Umsatz  Kund. Anz.  Aktionsanteil  \
# FILIALE
# 1             1       448.37  143673.336250       28791       0.201713
# 2             1       511.89  262155.130000       34170       0.232969
# 3             1       657.41  241407.675000       28689       0.271193
# 4             1       619.38   28726.860625        4631       0.220241
# 5             1       596.48  241030.717500       43840       0.201226
#
#          Anteil Clever  Anteil Ja!Natürlich  Anteil Feinkost  \
# FILIALE
# 1             0.045785             0.079104         0.196146
# 2             0.052128             0.104318         0.138855
# 3             0.056540             0.072498         0.136722
# 4             0.047574             0.066292         0.154642
# 5             0.050459             0.075726         0.155439
#
#          Anteil Obst&Gemüse  Anteil BILLA Marke  Anteil BILLA Corso  \
# FILIALE
# 1                  0.136016            0.053144            0.006050
# 2                  0.136353            0.054445            0.004915
# 3                  0.109450            0.054680            0.004796
# 4                  0.124101            0.049628            0.004352
# 5                  0.137170            0.050934            0.006547
#
#          Anteil Getränke ohne Alkohol  Anteil Alkohol  \
# FILIALE
# 1                            0.101261        0.079907
# 2                            0.074863        0.081780
# 3                            0.093237        0.087159
# 4                            0.104212        0.104071
# 5                            0.091954        0.082042
#
#          ANZAHL_Verbrauchermärkte_im Umkreis von 20min  \
# FILIALE
# 1                                                 81.0
# 2                                                 79.0
# 3                                                 75.0
# 4                                                 82.0
# 5                                                 80.0
#
#          ANZAHL_Diskonter_im Umkreis von 20min  \
# FILIALE
# 1                                        203.0
# 2                                        199.0
# 3                                        194.0
# 4                                        202.0
# 5                                        203.0
#
#          KaufKraft_Drogeriefachhandel_KOPF  KaufKraft_Lebensmittelhandel_KOPF  \
# FILIALE
# 1                               576.923077                        2884.615385
# 2                               500.387898                        2470.907680
# 3                               409.544160                        2108.262108
# 4                               466.200466                        2331.002331
# 5                               452.771272                        2279.469165
#
#          Kaufkraft_KOPF
# FILIALE
# 1           3461.538462
# 2           2971.295578
# 3           2517.806268
# 4           2797.202797
# 5           2732.240437

# %%
df["B_LAND"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='B_LAND'>

# %%
gr_bland = df.groupby("B_LAND").agg("sum")
gr_bland
# Out:
#         VERKAUFS_M2        Umsatz  Kund. Anz.  Aktionsanteil  Anteil Clever  \
# B_LAND
# 1         107043.81  4.472639e+07     6930608      48.510317      12.916614
# 2          20440.07  8.415823e+06      884117      11.052836       2.496887
# 3         128986.72  5.051705e+07     5557317      66.606621      14.137614
# 4          73428.54  2.553197e+07     3050019      40.140496       7.215800
# 5          34570.12  1.423638e+07     1673124      17.230116       3.505973
# 6          78007.81  2.655777e+07     3276803      42.661796       8.358218
# 7          46438.53  1.601799e+07     1896900      22.713572       4.690529
# 8          25166.09  7.867442e+06      905261      12.315266       2.619629
# 9           5253.66  1.532053e+06      177680       3.232368       0.581233
#
#         Anteil Ja!Natürlich  Anteil Feinkost  Anteil Obst&Gemüse  \
# B_LAND
# 1                 14.164095        28.660496           23.870543
# 2                  1.908085         4.867920            3.754097
# 3                 13.555825        35.007106           23.276664
# 4                  8.576862        20.853908           13.255405
# 5                  4.241072         9.700334            7.411063
# 6                  7.808073        21.877890           13.413720
# 7                  4.273926        13.639431            7.944627
# 8                  2.251562         6.388900            5.190485
# 9                  0.380954         1.212467            0.840036
#
#         Anteil BILLA Marke  Anteil BILLA Corso  Anteil Getränke ohne Alkohol  \
# B_LAND
# 1                10.762113            0.847291                     17.897569
# 2                 1.753014            0.103944                      2.922585
# 3                12.164475            0.686849                     18.654604
# 4                 6.807646            0.392231                     10.206941
# 5                 3.273361            0.229868                      4.883688
# 6                 7.140562            0.388212                     10.085722
# 7                 4.272985            0.250477                      5.931068
# 8                 2.358292            0.168455                      3.379869
# 9                 0.474874            0.029939                      0.974754
#
#         Anteil Alkohol  ANZAHL_Verbrauchermärkte_im Umkreis von 20min  \
# B_LAND
# 1            16.075889                                        14329.0
# 2             2.777936                                          133.0
# 3            17.566554                                         2575.0
# 4            11.594318                                         1332.0
# 5             6.095276                                          477.0
# 6            13.913610                                          935.0
# 7             7.893902                                          448.0
# 8             4.763933                                          333.0
# 9             1.670036                                          113.0
#
#         ANZAHL_Diskonter_im Umkreis von 20min  \
# B_LAND
# 1                                     36494.0
# 2                                       339.0
# 3                                      7400.0
# 4                                      3365.0
# 5                                      1196.0
# 6                                      2821.0
# 7                                      1064.0
# 8                                       338.0
# 9                                       187.0
#
#         KaufKraft_Drogeriefachhandel_KOPF  KaufKraft_Lebensmittelhandel_KOPF  \
# B_LAND
# 1                            92039.039204                      458581.031878
# 2                            14195.242804                       73182.158411
# 3                            93766.042691                      479271.373947
# 4                            53410.490214                      273879.037685
# 5                            27397.780145                      140064.893144
# 6                            56401.855655                      290551.272176
# 7                            33505.964207                      172383.239820
# 8                            18994.956399                       97876.315727
# 9                             4600.159133                       23374.422975
#
#         Kaufkraft_KOPF
# B_LAND
# 1        550620.071083
# 2         87377.401215
# 3        573037.416638
# 4        327289.527899
# 5        167462.673289
# 6        346953.127831
# 7        205889.204027
# 8        116871.272126
# 9         27974.582108

# %%
df_grouped_anteils= df[["B_LAND","Anteil Clever", "Anteil Ja!Natürlich", "Anteil Feinkost", "Anteil Obst&Gemüse", "Anteil BILLA Marke", "Anteil BILLA Corso", "Anteil Getränke ohne Alkohol", "Anteil Alkohol"]].groupby("B_LAND").agg("sum")
for index, row in df_grouped_anteils.iterrows():
    plt.figure(figsize=(8, 6))  # Adjust the figure size as needed
    sns.barplot(x=row.index, y=row.values)
    plt.xlabel('Sum')
    plt.ylabel('Features')
    plt.title(f'B_LAND {index}')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# The data is grouped by Bundesland.
# We can see that the majority of the discounts wich people use is the Feinkost and Fruits and Vegitables.
# The Alcohol was also strong 3rd position discount, especially at Bundesland 9, 8, 7 and 6, but pay attention to the scale... All of them alcohol exists as 3rd position.
#
# We can aslo see strong correclation between Clever and Biulla because Clever is sub-company of BILLA?
#
# This can help us to target based on the region and the revenue the discounts whcih can be offered to people.

# %%
sns.barplot(x=gr_bland.index, y=gr_bland.Umsatz)
# Out:
# <Axes: xlabel='B_LAND', ylabel='Umsatz'>

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(df.corr(),annot=True, cmap="coolwarm_r", annot_kws={"fontsize":10}, fmt=".2f", vmin=-1)
# Out:
# <Axes: >

# %% [markdown]
# As I anticipated... The revenue correlates high with the high number of customers. As well we have really high correlation in the features which are describing the shops in the area within 20 minutes. For our machine learning part they wouldnt be necessary because we will get multicolinearity and will harm our linear models. Which means that our coefficients will become 0.

# %%
plt.figure(figsize=(10,8))
sns.lineplot(x=df.groupby("B_LAND").agg("sum").index, y=df.groupby("B_LAND").agg("sum")["KaufKraft_Drogeriefachhandel_KOPF"], label='Drogeriefachhandel')
sns.lineplot(x=df.groupby("B_LAND").agg("sum").index, y=df.groupby("B_LAND").agg("sum")["KaufKraft_Lebensmittelhandel_KOPF"], label='Lebensmittelhandel')
plt.xlabel("Num of Bundesland")
plt.ylabel("Total ammount per Bundesland")
# Out:
# Text(0, 0.5, 'Total ammount per Bundesland')

# %% [markdown]
# Here we can see the correlation as well how those 2 lines are moving.

# %%
for i in ["Anteil Feinkost", "Anteil Obst&Gemüse", "Anteil Getränke ohne Alkohol"]:
    sns.histplot(df[i])
    plt.show()

# %%
sns.histplot(df["Kaufkraft_KOPF"])
plt.show()

# %% [markdown]
# We have pretty much normal distribution on the sales of the top parts for the all Bundes regions (which is expected from the law of big numbers)

# %%
sns.histplot(df["ANZAHL_Diskonter_im Umkreis von 20min"])
plt.show()

# %%
sns.histplot(df["ANZAHL_Verbrauchermärkte_im Umkreis von 20min"])
plt.show()
#Kaufkraft_KOPF

# %% [markdown]
# For those features ("ANZAHL_Verbrauchermärkte_im Umkreis von 20min" and  "ANZAHL_Diskonter_im Umkreis von 20min") we have not only high correllation, missing values but also not normal distribution in the data which can harm our linear models, ANOVA statistical testing.
#
# If the problem was the lack of Gaussian distribution we could just use data transformation (logaritmic) in order to hande it.
# So Im not going to use those columns.

# %% [markdown]
# # Machine Learning

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV

from sklearn.linear_model import LogisticRegressionCV

from sklearn.svm import SVC

from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier

from sklearn.neighbors import KNeighborsClassifier, NeighborhoodComponentsAnalysis

from sklearn.decomposition import PCA

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

from lightgbm import LGBMClassifier
from sklearn.pipeline import make_pipeline
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# Before the cluserting I would like to assume a standard classification problem - predict the Bundesland based on the data we are giving. So for now Ill assume that the predictor will be B_Land.
#
# After that I will threat the data as unsupervised in order to see how clustering methods will split and classify the data itself.

# %%
df_dropped = df.drop(["KaufKraft_Lebensmittelhandel_KOPF", "KaufKraft_Drogeriefachhandel_KOPF", "Kaufkraft_KOPF", "ANZAHL_Verbrauchermärkte_im Umkreis von 20min", "ANZAHL_Diskonter_im Umkreis von 20min"], axis=1)
df_dropped
# Out:
#          B_LAND  VERKAUFS_M2         Umsatz  Kund. Anz.  Aktionsanteil  \
# FILIALE
# 1             1       448.37  143673.336250       28791       0.201713
# 2             1       511.89  262155.130000       34170       0.232969
# 3             1       657.41  241407.675000       28689       0.271193
# 4             1       619.38   28726.860625        4631       0.220241
# 5             1       596.48  241030.717500       43840       0.201226
# ...         ...          ...            ...         ...            ...
# 938           6       591.86  197737.493125       24849       0.310716
# 939           8       483.18  155923.951875       18015       0.297161
# 940           6       525.17  151635.851250       20706       0.294699
# 941           3       518.63  198586.055000       17831       0.306065
# 942           2       493.52   99922.210000       10272       0.286408
#
#          Anteil Clever  Anteil Ja!Natürlich  Anteil Feinkost  \
# FILIALE
# 1             0.045785             0.079104         0.196146
# 2             0.052128             0.104318         0.138855
# 3             0.056540             0.072498         0.136722
# 4             0.047574             0.066292         0.154642
# 5             0.050459             0.075726         0.155439
# ...                ...                  ...              ...
# 938           0.047381             0.044325         0.202155
# 939           0.051160             0.039455         0.156178
# 940           0.056198             0.049958         0.178710
# 941           0.055478             0.053974         0.149726
# 942           0.061224             0.057060         0.144048
#
#          Anteil Obst&Gemüse  Anteil BILLA Marke  Anteil BILLA Corso  \
# FILIALE
# 1                  0.136016            0.053144            0.006050
# 2                  0.136353            0.054445            0.004915
# 3                  0.109450            0.054680            0.004796
# 4                  0.124101            0.049628            0.004352
# 5                  0.137170            0.050934            0.006547
# ...                     ...                 ...                 ...
# 938                0.081646            0.050574            0.002490
# 939                0.090566            0.054501            0.002342
# 940                0.090633            0.052398            0.003244
# 941                0.103228            0.053837            0.003411
# 942                0.099798            0.051480            0.003111
#
#          Anteil Getränke ohne Alkohol  Anteil Alkohol
# FILIALE
# 1                            0.101261        0.079907
# 2                            0.074863        0.081780
# 3                            0.093237        0.087159
# 4                            0.104212        0.104071
# 5                            0.091954        0.082042
# ...                               ...             ...
# 938                          0.067210        0.100661
# 939                          0.078724        0.097497
# 940                          0.093686        0.117182
# 941                          0.089459        0.090989
# 942                          0.097276        0.090092
#
# [942 rows x 13 columns]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df_dropped.drop("B_LAND", axis=1), df_dropped["B_LAND"], train_size=0.8)

# %%
scaler = MinMaxScaler()

X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

# %%
models_to_fit = [LogisticRegressionCV(), RandomForestClassifier(), SVC(), AdaBoostClassifier(), LGBMClassifier()]

# %%
def GetModelScores (estimator, X_train, y_train):
    scores_train = pd.DataFrame(columns= ['Accuracy','F1 Score','Precision','Recall','ROC_AUC'])
    scores_test = pd.DataFrame(columns= ['Accuracy','F1 Score','Precision','Recall','ROC_AUC'])
    
    model = estimator
    model.fit(X_train, y_train)
    
    prediction_train = model.predict(X_train)
    #prediction_test = model.predict(X_test)
    
    try:
        score_train = model.predict_proba(X_train)[:,1]
        roc_train= roc_auc_score(y_train, score_train, average = "weighted")
    except:
        roc_train = 0

    '''
    try:
        score_test = model.predict_proba(X_test)[:,1]
        roc_test= roc_auc_score(y_test, score_test, average = "weighted")
    except:
        roc_test = 0
    '''
    
    
    scores_train['Accuracy'] = accuracy_score(y_train, prediction_train)*100,
    scores_train['F1 Score'] = f1_score(y_train, prediction_train, average = "weighted")*100,
    scores_train['Precision'] = precision_score(y_train, prediction_train, average = "weighted")*100,
    scores_train['Recall'] = recall_score(y_train, prediction_train, average = "weighted")*100,
    scores_train['ROC_AUC'] = roc_train*100
    
    '''
    scores_test['Accuracy'] = accuracy_score(y_test, prediction_test)*100,
    scores_test['F1 Score'] = f1_score(y_test, prediction_test, average = "weighted")*100,
    scores_test['Precision'] = precision_score(y_test, prediction_test, average = "weighted")*100,
    scores_test['Recall'] = recall_score(y_test, prediction_test, average = "weighted")*100,
    scores_test['ROC_AUC'] = roc_test*100
    '''
    print(scores_train)

# %%
for i in models_to_fit:
    print(f"Fitting model {i.__class__}")
    GetModelScores(i, X_train_sc, Y_train)
    print("=====================================================")
# Out:
# Fitting model <class 'sklearn.linear_model._logistic.LogisticRegressionCV'>
# /mnt/d/projects/2rundJo/jovenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /mnt/d/projects/2rundJo/jovenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /mnt/d/projects/2rundJo/jovenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /mnt/d/projects/2rundJo/jovenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /mnt/d/projects/2rundJo/jovenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /mnt/d/projects/2rundJo/jovenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#     Accuracy   F1 Score  Precision     Recall  ROC_AUC
# 0  67.729084  67.307543  67.526188  67.729084        0
# =====================================================
# Fitting model <class 'sklearn.ensemble._forest.RandomForestClassifier'>
#    Accuracy  F1 Score  Precision  Recall  ROC_AUC
# 0     100.0     100.0      100.0   100.0        0
# =====================================================
# Fitting model <class 'sklearn.svm._classes.SVC'>
#     Accuracy   F1 Score  Precision     Recall  ROC_AUC
# 0  66.932271  65.076266  68.968855  66.932271        0
# =====================================================
# Fitting model <class 'sklearn.ensemble._weight_boosting.AdaBoostClassifier'>
# /mnt/d/projects/2rundJo/jovenv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#     Accuracy   F1 Score  Precision     Recall  ROC_AUC
# 0  37.981408  27.139427  26.884398  37.981408        0
# =====================================================
# Fitting model <class 'lightgbm.sklearn.LGBMClassifier'>
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000204 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3012
# [LightGBM] [Info] Number of data points in the train set: 753, number of used features: 12
# [LightGBM] [Info] Start training from score -1.536469
# [LightGBM] [Info] Start training from score -3.222868
# [LightGBM] [Info] Start training from score -1.453581
# [LightGBM] [Info] Start training from score -1.951236
# [LightGBM] [Info] Start training from score -2.546528
# [LightGBM] [Info] Start training from score -1.923585
# [LightGBM] [Info] Start training from score -2.465182
# [LightGBM] [Info] Start training from score -3.068717
# [LightGBM] [Info] Start training from score -4.321480
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#    Accuracy  F1 Score  Precision  Recall  ROC_AUC
# 0     100.0     100.0      100.0   100.0        0
# =====================================================

# %%
lg = LogisticRegressionCV()
lg.fit(X_train_sc, Y_train)
# Out:
# /mnt/d/projects/2rundJo/jovenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /mnt/d/projects/2rundJo/jovenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /mnt/d/projects/2rundJo/jovenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /mnt/d/projects/2rundJo/jovenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /mnt/d/projects/2rundJo/jovenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /mnt/d/projects/2rundJo/jovenv/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegressionCV()

# %%
def plot_matrix(X, Y, estimator):
    predictions = lg.predict(X)
    cm = confusion_matrix(Y, predictions, labels=estimator.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                display_labels=estimator.classes_)
    disp.plot()
    print("F1 score is: ",f1_score(Y, predictions, average="weighted"))

# %%
plot_matrix(X_train_sc, Y_train, lg)
# Out:
# F1 score is:  0.6730754330876073

# %%
plot_matrix(X_test_sc, Y_test, lg)

f1_score(Y_test, lg.predict(X_test_sc), average = "weighted")
# Out:
# F1 score is:  0.6326298814313934
# 0.6326298814313934

# %% [markdown]
# The thata clearly underfits.
#
# Ways to tackle this problem:
# 1. More data
# 2. More complex model
# 3. Get more features which we can use

# %%
k_fold = StratifiedKFold(n_splits = 5)
parameters = {
    "n_estimators": [50, 200, 400],
    "max_depth": [10, 50, 70]
}
grid_forest = GridSearchCV(RandomForestClassifier(), parameters, scoring = 'accuracy', cv = k_fold, n_jobs =-1)
grid_forest.fit(X_train_sc, Y_train)

grid_forest.best_estimator_
# Out:
# RandomForestClassifier(max_depth=70, n_estimators=200)

# %%
grid_forest.cv_results_
# Out:
# {'mean_fit_time': array([0.19829645, 0.55111499, 1.11427484, 0.13938522, 0.61147051,
#         1.23195276, 0.15481725, 0.61490374, 0.95523391]),
#  'std_fit_time': array([0.09523941, 0.07433188, 0.14989993, 0.02938936, 0.01034257,
#         0.01672013, 0.00408658, 0.00426258, 0.04915285]),
#  'mean_score_time': array([0.00965505, 0.01934242, 0.03679309, 0.00651884, 0.02296214,
#         0.03784728, 0.00717773, 0.02286892, 0.02865305]),
#  'std_score_time': array([0.00064745, 0.00412834, 0.0082319 , 0.00137126, 0.00100575,
#         0.00280418, 0.00053765, 0.0009866 , 0.00171605]),
#  'param_max_depth': masked_array(data=[10, 10, 10, 50, 50, 50, 70, 70, 70],
#               mask=[False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[50, 200, 400, 50, 200, 400, 50, 200, 400],
#               mask=[False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_depth': 10, 'n_estimators': 50},
#   {'max_depth': 10, 'n_estimators': 200},
#   {'max_depth': 10, 'n_estimators': 400},
#   {'max_depth': 50, 'n_estimators': 50},
#   {'max_depth': 50, 'n_estimators': 200},
#   {'max_depth': 50, 'n_estimators': 400},
#   {'max_depth': 70, 'n_estimators': 50},
#   {'max_depth': 70, 'n_estimators': 200},
#   {'max_depth': 70, 'n_estimators': 400}],
#  'split0_test_score': array([0.54966887, 0.52317881, 0.53642384, 0.53642384, 0.54304636,
#         0.56953642, 0.55629139, 0.56953642, 0.54304636]),
#  'split1_test_score': array([0.59602649, 0.60927152, 0.63576159, 0.54966887, 0.64900662,
#         0.59602649, 0.57615894, 0.65562914, 0.61589404]),
#  'split2_test_score': array([0.52980132, 0.50331126, 0.51655629, 0.51655629, 0.50993377,
#         0.49668874, 0.54966887, 0.51655629, 0.51655629]),
#  'split3_test_score': array([0.54666667, 0.54      , 0.54      , 0.55333333, 0.52666667,
#         0.55333333, 0.52666667, 0.54666667, 0.51333333]),
#  'split4_test_score': array([0.55333333, 0.60666667, 0.58666667, 0.56      , 0.58      ,
#         0.59333333, 0.57333333, 0.56666667, 0.6       ]),
#  'mean_test_score': array([0.55509934, 0.55648565, 0.56308168, 0.54319647, 0.56173068,
#         0.56178366, 0.55642384, 0.57101104, 0.557766  ]),
#  'std_test_score': array([0.02199427, 0.04361908, 0.04300381, 0.01537904, 0.04942139,
#         0.03615748, 0.01792508, 0.04634488, 0.04254821]),
#  'rank_test_score': array([8, 6, 2, 9, 4, 3, 7, 1, 5], dtype=int32)}

# %%
plot_matrix(X_test_sc, Y_test, grid_forest)
# Out:
# F1 score is:  0.6326298814313934

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_sc, Y_train)

plot_matrix(X_test_sc, Y_test, knn)
# Out:
# F1 score is:  0.6326298814313934

# %%
# Reduce dimension to 2 with PCA
pca = make_pipeline(MinMaxScaler(), PCA(n_components=2, random_state=random_state))
# Reduce dimension to 2 with LinearDiscriminantAnalysis
lda = make_pipeline(MinMaxScaler(), LinearDiscriminantAnalysis(n_components=2))
# Reduce dimension to 2 with NeighborhoodComponentAnalysis
nca = make_pipeline(
    MinMaxScaler(),
    NeighborhoodComponentsAnalysis(n_components=2, random_state=random_state)
)
knn = KNeighborsClassifier(n_neighbors=5)

# %%
# Make a list of the methods to be compared
dim_reduction_methods = [("PCA", pca), ("LDA", lda), ("NCA", nca)]

# plt.figure()
for i, (name, model) in enumerate(dim_reduction_methods):
    plt.figure()
    # plt.subplot(1, 3, i + 1, aspect=1)

    # Fit the method's model
    model.fit(X_train, Y_train)

    # Fit a nearest neighbor classifier on the embedded training set
    knn.fit(model.transform(X_train), Y_train)

    # Compute the nearest neighbor accuracy on the embedded test set
    acc_knn = knn.score(model.transform(X_test), Y_test)

    # Embed the data set in 2 dimensions using the fitted model
    X_embedded = model.transform(X_train)

    # Plot the projected points and show the evaluation score
    plt.scatter(X_embedded[:, 0], X_embedded[:, 1], c=Y_train, s=30, cmap="Set1")
    plt.title(
        "{}, KNN (k={})\nTest accuracy = {:.2f}".format(name, n_neighbors, acc_knn)
    )
plt.show()

# %% [markdown]
# I will use UMAP technique in order to vizualize the data into 2 dimension scpase. This technique has eseveral advantages: Preservation of Global Structure - takes into account all points not just nearby

# %%
import umap
ump = umap.UMAP(random_state=42)
umap_data = ump.fit_transform(X_train)
plt.figure(figsize=(20,12))
sns.scatterplot(x=umap_data[:,0], y=umap_data[:,1], hue=Y_train, palette='cool')
plt.show()

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=0.50, min_samples=5)
dbscan.fit(umap_data)
DBSCAN(eps=0.32)
plt.figure(figsize=(20,12))
sns.scatterplot(x=umap_data[:,0], y=umap_data[:,1], hue=dbscan.labels_, palette='Set2')
plt.show()

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train, Y_train)

f1_score(Y_train, dt.predict(X_train), average="weighted")

pd.DataFrame({"Features":X_train.columns, "Importance":dt.feature_importances_}).sort_values("Importance")
# Out:
#                         Features  Importance
# 9             Anteil BILLA Corso    0.034017
# 2                     Kund. Anz.    0.055762
# 4                  Anteil Clever    0.066846
# 0                    VERKAUFS_M2    0.068652
# 1                         Umsatz    0.071360
# 5            Anteil Ja!Natürlich    0.071572
# 7             Anteil Obst&Gemüse    0.086962
# 8             Anteil BILLA Marke    0.094826
# 11                Anteil Alkohol    0.095277
# 6                Anteil Feinkost    0.102566
# 10  Anteil Getränke ohne Alkohol    0.108642
# 3                  Aktionsanteil    0.143519

# %%
plt.figure(figsize=(20,12))
important_features = df[["Aktionsanteil", "Anteil Getränke ohne Alkohol"]]
sns.scatterplot(x=important_features["Aktionsanteil"], y=important_features["Anteil Getränke ohne Alkohol"], hue=df["B_LAND"], palette='cool')
plt.show()
